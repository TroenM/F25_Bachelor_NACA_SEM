# %%
import os
os.chdir("../../")
from Potential_flow_solver.PotentialFlowSolverCLS.PotentialFlowSolver import *
os.chdir("../../Visualisation/PotentialFlowCL")
# Out:
# Libraries fetched!...

# %%
nasa_cl = np.loadtxt("/home/firedrake/Projects/Bachelor/F25_Bachelor_NACA_SEM/Visualisation/LiftCoeffPlot/nasa_cl.txt")
circular_cl = np.loadtxt("/home/firedrake/Projects/Bachelor/F25_Bachelor_NACA_SEM/Visualisation/LiftCoeffPlot/circular_cl_point.txt")
eliptic_cl = np.loadtxt("/home/firedrake/Projects/Bachelor/F25_Bachelor_NACA_SEM/Visualisation/LiftCoeffPlot/eliptic_cl_point.txt")

# %%
2*np.pi/(2*np.pi*np.sqrt(0.65))
# Out:
# np.float64(1.2403473458920844)

# %%
circular_cl[:,1]/ nasa_cl[:,1]
# Out:
# /tmp/ipykernel_887303/3344129633.py:1: RuntimeWarning: divide by zero encountered in divide
#   circular_cl[:,1]/ nasa_cl[:,1]
# array([1.87474719, 1.60063594, 1.37038488, 1.33287513, 1.29914947,
#        1.26247514, 1.24374084, 1.22275564, 1.21385938, 1.24572904,
#        1.23641085, 1.24822934, 1.24577847, 1.13807219,       -inf,
#        0.9739537 , 1.13971249, 1.08462703, 1.09400841, 1.10915351,
#        1.14872174, 1.15611029, 1.16420624, 1.18769388, 1.25288823,
#        1.3714904 , 1.77373999, 2.13034023])

# %%
plt.plot(nasa_cl[:,0], nasa_cl[:,1], label='NASA experimental')
plt.plot(circular_cl[:,0], circular_cl[:,1], label='Circular vortex')
plt.plot(eliptic_cl[:,0], eliptic_cl[:,1], label='Elliptic vortex')

plt.legend()  # Show legend
plt.xlabel('AoA')  # Optional
plt.ylabel('Lift coefficient')  # Optional
plt.title('Comparison Plot')  # Optional

plt.show()
